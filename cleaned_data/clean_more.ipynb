# %% [markdown]
# <a href="https://colab.research.google.com/github/maggiecrowner/DS-2002-F25/blob/main/cleaned_data/clean_more.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data cleaning, continued
#
# Data cleaning as appropriate for this specific analysis

# %%
! git clone https://github.com/ashritakodali/coffee_quality_analysis.git
# Out:
# Cloning into 'coffee_quality_analysis'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 45 (delta 8), reused 8 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 176.81 KiB | 7.69 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
import pandas as pd
import numpy as np

arabica = pd.read_csv()
